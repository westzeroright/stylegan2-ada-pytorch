# %%
# !pip install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3

# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# Out:
# fatal: destination path 'stylegan2-ada-pytorch' already exists and is not an empty directory.

# %%
import os

# %%
os.chdir('stylegan2-ada-pytorch')

# %%
# !pwd
# Out:
# /content/stylegan2-ada-pytorch

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !python dataset_tool.py --source /content/gdrive/MyDrive/folder/size --dest /content/gdrive/MyDrive/folder/tf
# Out:
# 100% 1000/1000 [01:52<00:00,  8.91it/s]

# %%
# !python train.py --outdir=/content/gdrive/MyDrive/folder/output --snap 25 --data=/content/gdrive/MyDrive/folder/tf
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/stylegan2-ada-pytorch/torch_utils/ops/conv2d_gradfix.py:55: UserWarning: conv2d_gradfix not supported on PyTorch 2.3.1+cu121. Falling back to torch.nn.functional.conv2d().
#   warnings.warn(f'conv2d_gradfix not supported on PyTorch {torch.__version__}. Falling back to torch.nn.functional.conv2d().')
# /content/stylegan2-ada-pytorch/torch_utils/ops/conv2d_gradfix.py:55: UserWarning: conv2d_gradfix not supported on PyTorch 2.3.1+cu121. Falling back to torch.nn.functional.conv2d().
#   warnings.warn(f'conv2d_gradfix not supported on PyTorch {torch.__version__}. Falling back to torch.nn.functional.conv2d().')
# /content/stylegan2-ada-pytorch/torch_utils/ops/conv2d_gradfix.py:55: UserWarning: conv2d_gradfix not supported on PyTorch 2.3.1+cu121. Falling back to torch.nn.functional.conv2d().
#   warnings.warn(f'conv2d_gradfix not supported on PyTorch {torch.__version__}. Falling back to torch.nn.functional.conv2d().')
# ...
